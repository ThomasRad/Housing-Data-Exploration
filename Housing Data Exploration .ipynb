# %% [markdown]
# ### This will just but a quick little data exploration of the boston housing dataset.

# %%
# Load the packages we will need later

import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
# Load the dataset  

housing_df = pd.read_csv('Bostonhousing.csv')

# %%
#See that everything is okay. Good. 

housing_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PT RATIO  LSTAT  MEDV  CAT. MEDV
# 0        15.3   4.98  24.0          0
# 1        17.8   9.14  21.6          0
# ...

# %%
# Lets see how many rows and columns the dataset has. 

housing_df.shape
# Out:
# (506, 14)

# %%
# Check out the various columns

housing_df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PT RATIO', 'LSTAT', 'MEDV', 'CAT. MEDV'],
#       dtype='object')

# %%
# And since we are at it check the data types too. 

housing_df.dtypes
# Out:
# CRIM         float64
# ZN           float64
# INDUS        float64
# CHAS           int64
# NOX          float64
# RM           float64
# AGE          float64
# DIS          float64
# RAD            int64
# TAX            int64
# PT RATIO     float64
# LSTAT        float64
# MEDV         float64
# CAT. MEDV      int64
# dtype: object

# %%
# If I want to check the first few entries. 

housing_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PT RATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296      15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242      17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242      17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222      18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222      18.7
#
#    LSTAT  MEDV  CAT. MEDV
# 0   4.98  24.0          0
# 1   9.14  21.6          0
# 2   4.03  34.7          1
# 3   2.94  33.4          1
# 4   5.33  36.2          1

# %%
# Or maybe just the last few 

housing_df.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PT RATIO  LSTAT  MEDV  CAT. MEDV
# 501      21.0   9.67  22.4          0
# 502      21.0   9.08  20.6          0
# 503      21.0   5.64  23.9          0
# 504      21.0   6.48  22.0          0
# 505      21.0   7.88  11.9          0

# %%
# Lets look at some basic stats about the dataset. 

housing_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX    PT RATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %%
# Check for if we have any null values. Looks like there aren't any. 

housing_df.isnull().sum()
# Out:
# CRIM         0
# ZN           0
# INDUS        0
# CHAS         0
# NOX          0
# RM           0
# AGE          0
# DIS          0
# RAD          0
# TAX          0
# PT RATIO     0
# LSTAT        0
# MEDV         0
# CAT. MEDV    0
# dtype: int64

# %%
#Visually see the distribution of MEDV, the target variable for this dataset. 

sns.histplot(housing_df,x = 'MEDV')

# %%
# Here we just want to see which variables are pair-wise correlated with the target variable 

corr = housing_df.corr()

#Lets look at the abs corr. 

abs_cor = corr.abs()
abs_cor

#And Now we just want to look at which ones have the highest and filter for those. 

sta = abs_cor.unstack()
so = sta.sort_values(kind="quicksort")
so.MEDV
# Out:
# CHAS         0.175260
# DIS          0.249929
# ZN           0.360445
# AGE          0.376955
# RAD          0.381626
# CRIM         0.388305
# NOX          0.427321
# TAX          0.468536
# INDUS        0.483725
# PT RATIO     0.507787
# RM           0.695360
# LSTAT        0.737663
# CAT. MEDV    0.789789
# MEDV         1.000000
# dtype: float64

# %%
#Lets look at the highest corr variables. We see that there is a negative trend. 

sns.scatterplot(data = housing_df,x='LSTAT', y = 'MEDV')

# %%
#Now checking for another variable with the target we see that there is a positive trend. 

sns.scatterplot(data = housing_df,x='RM', y = 'MEDV')

# %% [markdown]
# ### This was just a quick little module to look at very few aspects of the data set and some minor exploration we could potentially do.
